# %%
import pandas as pd

# %%
accepted_df = pd.read_csv(r"C:\Users\hadiy\Desktop\ML\src\data\datasets\versions\3\accepted_2007_to_2018q4.csv\accepted_2007_to_2018Q4.csv")
rejected_df = pd.read_csv(r"C:\Users\hadiy\Desktop\ML\src\data\datasets\versions\3\rejected_2007_to_2018q4.csv\rejected_2007_to_2018Q4.csv")

# %%
accepted_df["hardship_loan_status"].

# %%
rejected_df.head()
