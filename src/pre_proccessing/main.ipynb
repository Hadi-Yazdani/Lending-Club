# %%
import pandas as pd

# %%
accepted_df = pd.read_csv(r"C:\Users\hadiy\Desktop\ML\src\data\datasets\versions\3\accepted_2007_to_2018q4.csv\accepted_2007_to_2018Q4.csv")
rejected_df = pd.read_csv(r"C:\Users\hadiy\Desktop\ML\src\data\datasets\versions\3\rejected_2007_to_2018q4.csv\rejected_2007_to_2018Q4.csv")

# %%
accepted_df['issue_d'] = pd.to_datetime(accepted_df['issue_d'], format='%b-%Y')

# %%
accepted_36_month_population = accepted_df[
    (accepted_df['term'].str.strip() == '36 months')
    & (accepted_df['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default']))
    & (accepted_df['issue_d'] >= '2012-01-01')
    & (accepted_df['issue_d'] <= '2015-12-31')
]

# %%
accepted_36_month_population.iloc[0].to_dict()

# %%
accepted_df.iloc[0].to_dict()

# %%
accepted_df.shape[0]

# %%
accepted_36_month_population.shape[0]
